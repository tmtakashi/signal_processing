# %% [markdown]
# ## フィルタ設計

# %% [markdown]
# ### ローパスフィルター
#
# 零点が実軸上の原点より左側の位置にあればよい。
#
# 例えば
# $$
# H(z) = \frac{(z + 1)^2}{z^2} \\
#         = 1 + 2z + z^{-2}\\
# \therefore y[n] = x[n] + 2x[n - 1] + x[x -2]
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

fs = 48000

# %%
from scipy.signal import lfilter, freqz

b = [1, 2, 1]
a = [1]

w, h = freqz(b, a, fs=fs)

plt.plot(w, 20*np.log10(np.abs(h)))
plt.title('Low Pass Filter')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Amplitude [dB]')
# Out:
# Text(0, 0.5, 'Amplitude [dB]')

# %% [markdown]
# ### ハイパスフィルター
#
# 零点が実軸上の原点より右側の位置ににあればよい。
#
# 例えば
# $$
# H(z) = \frac{(z - 1)^2}{z^2} \\
#         = 1 + 2z + z^{-2}\\
# \therefore y[n] = x[n] - 2x[n - 1] + x[x -2]
# $$

# %%
b = [1, -2, 1]
a = [1]

w, h = freqz(b, a, fs=fs)

plt.plot(w, 20*np.log10(np.abs(h)))
plt.title('High Pass Filter')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Amplitude [dB]')
# Out:
# /Users/takashiminagawa/.pyenv/versions/3.6.5/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log10
# Text(0, 0.5, 'Amplitude [dB]')

# %% [markdown]
# ### ノッチフィルタ
#
# 極が任意の周波数に対応する角度の位置にあり、単位円の内側にあればよい
#
# 例えば
#
# $$
# z_1 = \frac{2 + j\sqrt{3}}{2}\\
# z_2 = \frac{2 - j\sqrt{3}}{2}\\
# H(z) = \frac{z^2}{(z - z_1)(z - z_2)} \\
#         = \frac{1}{1 - (z_1 + z_2)z + z_1z_2z^{-2}}\\
# \therefore y[n] - (z_1 + z_2)y[n -1] + z_1z_2y[n-2] = x[n]
# $$

# %%
z1 = 0.5 * complex(2, np.sqrt(3))
z2 = z1.conjugate()

b = [1]
a = [1, -(z1 + z2) , z1 * z2]

w, h = freqz(b, a, fs=fs)

plt.plot(w, 20*np.log10(np.abs(h)))
plt.title('Notch Filter')
plt.xlabel('Frequency[Hz]')
plt.ylabel('Amplitude [dB]')
# Out:
# Text(0, 0.5, 'Amplitude [dB]')

# %% [markdown]
# ### 全極型スペクトルによる声道特性の表現
#
# ２次の全極型フィルタの極を$z_1, z_2$とする。
#
# $$
# z_1 = re^{j\Omega}, z_2 = re^{-j\Omega}
# $$
#
# 伝達関数は
#
# $$
# H(z) = \frac{z^2}{z^2 - (2r\cos{\Omega})z + r^2}
# $$
#
# この$H(z)$に対応する差分方程式は
#
# $$
# y[n] = (2r\cos{\Omega})y[n-1] -r^2y[n-2] + x[n]
# $$
#
# 2個のフォルマントを表現するために2個の2次システムを縦続接続する。

# %%
def get_2d_AR(r, omega, fs=8000):
    b = [1]
    a = [1, -2*r*np.cos(omega), r**2]
    
    w, h = freqz(b, a, fs=fs)
    
    return w, h

r1 = 0.9
omega1 = np.pi / 8

r2 = 0.9
omega2 = np.pi / 3

r3 = 0.9
omega3 = 2 / 3 * np.pi 

r4 = 0.8
omega4 = 7 / 8 * np.pi

w, H1 = get_2d_AR(r1, omega1)
w, H2 = get_2d_AR(r2, omega2)
w, H3 = get_2d_AR(r3, omega3)
w, H4 = get_2d_AR(r4, omega4)

H = H1 * H2 * H3 * H4

plt.figure(figsize=(15, 7))

plt.subplot(2, 3, 1)
plt.plot(w, 20*np.log10(np.abs(H1)))
plt.title('$H_1(z)$')
plt.xlabel('Frequency[Hz]')
plt.ylabel('Amplitude [dB]')

plt.subplot(2, 3, 2)
plt.plot(w, 20*np.log10(np.abs(H2)))
plt.title('$H_2(z)$')
plt.xlabel('Frequency[Hz]')
plt.ylabel('Amplitude [dB]')

plt.subplot(2, 3, 3)
plt.plot(w, 20*np.log10(np.abs(H3)))
plt.title('$H_3(z)$')
plt.xlabel('Frequency[Hz]')
plt.ylabel('Amplitude [dB]')

plt.subplot(2, 3, 4)
plt.plot(w, 20*np.log10(np.abs(H4)))
plt.title('$H_4(z)$')
plt.xlabel('Frequency[Hz]')
plt.ylabel('Amplitude [dB]')

plt.subplot(2, 3, 5)
plt.plot(w, 20*np.log10(np.abs(H)))
plt.title('Vocal tract characteristics')
plt.xlabel('Frequency[Hz]')
plt.ylabel('Amplitude [dB]')

plt.tight_layout()
